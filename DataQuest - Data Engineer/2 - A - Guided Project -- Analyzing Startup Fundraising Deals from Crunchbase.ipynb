# %% [markdown]
# # Guided Project - Analyzing Startup Fundraising Deals from Crunchbase

# %%
import pandas as pd
pd.options.display.max_columns = 99

data = pd.read_csv('crunchbase-investments.csv',
                   encoding='ISO-8859-1',
                   low_memory=False)
data.head(5)
# Out:
#      company_permalink company_name company_category_code  \
# 0    /company/advercar     AdverCar           advertising
# 1  /company/launchgram   LaunchGram                  news
# 2        /company/utap         uTaP             messaging
# 3    /company/zoopshop     ZoopShop              software
# 4    /company/efuneral     eFuneral                   web
#
#   company_country_code company_state_code         company_region  \
# 0                  USA                 CA                 SF Bay
# 1                  USA                 CA                 SF Bay
# 2                  USA                NaN  United States - Other
# 3                  USA                 OH               Columbus
# 4                  USA                 OH              Cleveland
#
#     company_city          investor_permalink      investor_name  \
# 0  San Francisco  /company/1-800-flowers-com  1-800-FLOWERS.COM
# 1  Mountain View        /company/10xelerator        10Xelerator
# 2            NaN        /company/10xelerator        10Xelerator
# 3       columbus        /company/10xelerator        10Xelerator
# 4      Cleveland        /company/10xelerator        10Xelerator
#
#   investor_category_code investor_country_code investor_state_code  \
# 0                    NaN                   USA                  NY
# 1                finance                   USA                  OH
# 2                finance                   USA                  OH
# 3                finance                   USA                  OH
# 4                finance                   USA                  OH
#
#   investor_region investor_city funding_round_type   funded_at funded_month  \
# 0        New York      New York           series-a  2012-10-30      2012-10
# 1        Columbus      Columbus              other  2012-01-23      2012-01
# 2        Columbus      Columbus              other  2012-01-01      2012-01
# 3        Columbus      Columbus              angel  2012-02-15      2012-02
# 4        Columbus      Columbus              other  2011-09-08      2011-09
#
#   funded_quarter  funded_year  raised_amount_usd
# 0        2012-Q4       2012.0          2000000.0
# 1        2012-Q1       2012.0            20000.0
# 2        2012-Q1       2012.0            20000.0
# 3        2012-Q1       2012.0            20000.0
# 4        2011-Q3       2011.0            20000.0

# %%
chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     chunksize=5000)

memory_col= dict()
missing_value = dict()

memory = list()

for index,chunk in enumerate(chunks):
    memory.append(chunk.memory_usage(deep=True).sum()/(1024*1024))
    
    if index==0:
        for col in chunk.columns.tolist():
            memory_col[col]=list()
            missing_value[col]=list()
    
    for col in chunk.columns.tolist():
        memory_col[col].append(chunk[col].memory_usage(deep=True)/(1024*1024))   
        missing_value[col].append(chunk[col].isna().sum())

# %%
print('--'*15)    

for key,value in missing_value.items():
    print('Column {} - {} missing value(s)'.format(key,sum(value)))

print('--'*15)    
    
for key,value in memory_col.items():
    print('Column {} - Memory footprint {} MB'.format(key,round(sum(value),2)))

print('--'*15)    

print('Total Memory size : {} MB'.format(round(sum(memory),2)))
# Out:
# ------------------------------
# Column raised_amount_usd - 3599 missing value(s)
# Column funding_round_type - 3 missing value(s)
# Column company_region - 1 missing value(s)
# Column investor_state_code - 16809 missing value(s)
# Column funded_year - 3 missing value(s)
# Column company_city - 533 missing value(s)
# Column investor_country_code - 12001 missing value(s)
# Column company_category_code - 643 missing value(s)
# Column investor_city - 12480 missing value(s)
# Column investor_region - 2 missing value(s)
# Column funded_at - 3 missing value(s)
# Column investor_category_code - 50427 missing value(s)
# Column funded_month - 3 missing value(s)
# Column company_name - 1 missing value(s)
# Column company_state_code - 492 missing value(s)
# Column funded_quarter - 3 missing value(s)
# Column company_permalink - 1 missing value(s)
# Column investor_name - 2 missing value(s)
# Column company_country_code - 1 missing value(s)
# Column investor_permalink - 2 missing value(s)
# ------------------------------
# Column raised_amount_usd - Memory footprint 0.4 MB
# Column funding_round_type - Memory footprint 3.25 MB
# Column company_region - Memory footprint 3.25 MB
# Column investor_state_code - Memory footprint 2.36 MB
# Column funded_year - Memory footprint 0.4 MB
# Column company_city - Memory footprint 3.34 MB
# Column investor_country_code - Memory footprint 2.53 MB
# Column company_category_code - Memory footprint 3.26 MB
# Column investor_city - Memory footprint 2.75 MB
# Column investor_region - Memory footprint 3.24 MB
# Column funded_at - Memory footprint 3.38 MB
# Column investor_category_code - Memory footprint 0.59 MB
# Column funded_month - Memory footprint 3.23 MB
# Column company_name - Memory footprint 3.43 MB
# Column company_state_code - Memory footprint 2.96 MB
# Column funded_quarter - Memory footprint 3.23 MB
# Column company_permalink - Memory footprint 3.87 MB
# Column investor_name - Memory footprint 3.74 MB
# Column company_country_code - Memory footprint 3.03 MB
# Column investor_permalink - Memory footprint 4.75 MB
# ------------------------------
# Total Memory size : 56.99 MB

# %% [markdown]
# ## Selecting Data Types

# %%
col_types = list()

chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     chunksize=5000)

for index,chunk in enumerate(chunks):     
    if index==0:
        print(chunk.dtypes)
        col_types = chunk.columns.tolist()
# Out:
# company_permalink          object
# company_name               object
# company_category_code      object
# company_country_code       object
# company_state_code         object
# company_region             object
# company_city               object
# investor_permalink         object
# investor_name              object
# investor_category_code     object
# investor_country_code      object
# investor_state_code        object
# investor_region            object
# investor_city              object
# funding_round_type         object
# funded_at                  object
# funded_month               object
# funded_quarter             object
# funded_year                 int64
# raised_amount_usd         float64
# dtype: object

# %%
col_str_num = list()

for col in col_types:
    if col.endswith('_code'):
        col_str_num.append(col)

# %%
chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     chunksize=5000)

for index,chunk in enumerate(chunks):    
    for col in col_str_num:
        try:
            chunk[col] = pd.to_numeric(chunk[col])
        except:
            pass

# %%
chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     chunksize=5000)

candidates_category = list()

for index,chunk in enumerate(chunks):
    for col in chunk.columns.tolist():
        number_values_unique = len(chunk[col].unique())
        
        if number_values_unique <20:
            candidates_category.append(col)
            
category_cols = set(candidates_category)            

print(category_cols)
# Out:
# {'funding_round_type', 'funded_year', 'investor_country_code', 'investor_city', 'investor_region', 'investor_category_code', 'investor_state_code', 'company_country_code'}

# %%
convert_col_dtypes = dict()

for col in category_cols:
    convert_col_dtypes[col]='category'

chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     dtype=convert_col_dtypes, 
                     chunksize=5000)

# %%
memory = list()

for index,chunk in enumerate(chunks):
    memory.append(chunk.memory_usage(deep=True).sum()/(1024*1024))
    
print('Total Memory size : {} MB'.format(round(sum(memory),2)))
# Out:
# Total Memory size : 39.75 MB

# %%
# Drop columns representing URL's or containing way too many missing values (>90% missing)
drop_cols = ['investor_permalink', 'company_permalink', 'investor_category_code']

chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     dtype=convert_col_dtypes, 
                     chunksize=5000)

for chunk in chunks:
    chunk = chunk.drop(columns=drop_cols)

#keep_cols = chunk.columns.drop(drop_cols)

# %% [markdown]
# ## Loading Chunks into SQLite

# %%
import sqlite3

conn =sqlite3.connect('crunchbase.db')

chunks = pd.read_csv('crunchbase-investments.csv',
                     encoding='ISO-8859-1',
                     dtype=convert_col_dtypes, 
                     chunksize=5000)

for chunk in chunks:
    
    chunk = chunk.drop(columns=drop_cols)
    
    for col in col_str_num:
        try:
            chunk[col] = pd.to_numeric(chunk[col])
        except:
            pass
        
    chunk.to_sql("investments",conn
                              ,index=False
                              ,if_exists='append')

# %%
# !wc 'crunchbase.db'
# Out:
#    6096  236230 7520256 crunchbase.db

# %% [markdown]
# ## Data Exploration and Analysis

# %%
query = """
SELECT company_name,
        (SUM(raised_amount_usd)
        /(SELECT SUM(raised_amount_usd) FROM investments))
        AS Proportion
        FROM investments
        GROUP BY company_name
        ORDER BY Proportion DESC;
"""

top = pd.read_sql(query,conn)

# %%
top
# Out:
#                   company_name  Proportion
# 0                    Clearwire    0.043536
# 1                      Groupon    0.014940
# 2                    Nanosolar    0.006608
# 3                     Facebook    0.006093
# 4                 SurveyMonkey    0.004767
# 5                        Zynga    0.004233
# 6            Fisker Automotive    0.004090
# 7                      Dropbox    0.004055
# 8                 LivingSocial    0.003938
# 9                    sigmacare    0.003814
# 10                Bloom Energy    0.003711
# 11         Pacific Biosciences    0.003483
# 12                     Fab.com    0.003446
# 13         BrightSource Energy    0.003255
# 14                     TRUECar    0.003090
# 15              Wave Broadband    0.003080
# 16                     Twitter    0.002860
# 17                      PayPal    0.002724
# 18                    Solyndra    0.002689
# 19                Demand Media    0.002670
# 20                       KAYAK    0.002660
# 21                     MiaSol    0.002567
# 22                Tesla Motors    0.002547
# 23                Pure Storage    0.002420
# 24                   SunEdison    0.002399
# 25      Kosmos Biotherapeutics    0.002340
# 26                 Gilt Groupe    0.002282
# 27              NextG Networks    0.002259
# 28     Legendary Entertainment    0.002017
# 29                   Pinterest    0.001989
# ...                        ...         ...
# 11544                 gripNote         NaN
# 11545                 iCracked         NaN
# 11546                  iCreate         NaN
# 11547            iQ Media Corp         NaN
# 11548                 iVillage         NaN
# 11549         imbookin (Pogby)         NaN
# 11550                    imgIX         NaN
# 11551    imo instant messenger         NaN
# 11552                  inDplay         NaN
# 11553                 inFreeDA         NaN
# 11554              inSparq.com         NaN
# 11555    invisibleBracelet.org         NaN
# 11556                     lark         NaN
# 11557           mo9 (moKredit)         NaN
# 11558                mobiTeris         NaN
# 11559                mobintent         NaN
# 11560                my4oneone         NaN
# 11561     myEnergyPlatform.com         NaN
# 11562                 myZamana         NaN
# 11563               rag & bone         NaN
# 11564               relocality         NaN
# 11565                series-c+         NaN
# 11566                  tsumobi         NaN
# 11567                  vSocial         NaN
# 11568        vcopious Software         NaN
# 11569                 viaCycle         NaN
# 11570                weeSpring         NaN
# 11571                writewith         NaN
# 11572            xG Technology         NaN
# 11573                   zuuka!         NaN
#
# [11574 rows x 2 columns]

# %%
query = """
SELECT company_category_code,
        SUM(raised_amount_usd)/1000000 AS invest 
        
        FROM investments
        
        GROUP BY company_category_code
        ORDER BY invest DESC;
"""

category_invest = pd.read_sql(query,conn)

# %%
category_invest
# Out:
#    company_category_code         invest
# 0                biotech  110396.423062
# 1               software   73084.516724
# 2                 mobile   64777.379752
# 3              cleantech   52705.225028
# 4             enterprise   45860.927273
# 5                    web   40143.264989
# 6                medical   25367.105281
# 7            advertising   25076.661879
# 8              ecommerce   22567.220071
# 9        network_hosting   22419.683840
# 10         semiconductor   22358.337233
# 11              hardware   20945.450919
# 12           games_video   19409.648694
# 13             analytics   13744.234529
# 14              security   13149.871029
# 15                social   11530.430338
# 16               finance   11200.202551
# 17                health    8789.298501
# 18              nanotech    8458.320000
# 19      public_relations    7815.234000
# 20            automotive    7239.251580
# 21                 other    6266.440805
# 22                search    5847.789999
# 23                  None    5752.644931
# 24             education    5502.308542
# 25         manufacturing    5162.772010
# 26                  news    4916.763871
# 27               fashion    3902.203810
# 28                travel    3042.393144
# 29             messaging    2824.664780
# 30            consulting    1997.604000
# 31        transportation    1932.056000
# 32                 music    1930.396500
# 33           photo_video    1389.648500
# 34           hospitality    1267.434924
# 35           real_estate    1020.963564
# 36             nonprofit     513.834820
# 37                 legal     501.368000
# 38                design     302.640000
# 39                sports     279.045000
# 40                 local     210.360000
# 41                  pets     128.980000
# 42            government       1.187500
# 43                2/7/08            NaN

# %%
query = """
SELECT investor_name,
        SUM(raised_amount_usd)/1000000 AS invest 
        
        FROM investments
        
        GROUP BY investor_name
        ORDER BY invest DESC;
"""

investor = pd.read_sql(query,conn)

# %%
investor
# Out:
#                                            investor_name        invest
# 0                       Kleiner Perkins Caufield & Byers  11217.826376
# 1                              New Enterprise Associates   9692.542344
# 2                                         Accel Partners   6472.126199
# 3                                          Goldman Sachs   6375.459000
# 4                                        Sequoia Capital   6039.402410
# 5                                                  Intel   5969.200000
# 6                                                 Google   5808.800000
# 7                                            Time Warner   5730.000000
# 8                                                Comcast   5669.000000
# 9                                      Greylock Partners   4960.982939
# 10                                           BrightHouse   4700.000000
# 11                                         Intel Capital   4695.616755
# 12                         Draper Fisher Jurvetson (DFJ)   4501.461238
# 13                               Oak Investment Partners   4350.064727
# 14                                   Andreessen Horowitz   4233.673760
# 15                           Lightspeed Venture Partners   4140.979000
# 16                                             Benchmark   4119.948996
# 17                                      Battery Ventures   4054.531508
# 18                                     Redpoint Ventures   3974.377360
# 19                             Bessemer Venture Partners   3628.705002
# 20                                       Khosla Ventures   3570.408993
# 21                                   US Venture Partners   3520.819998
# 22                                               Venrock   3353.219998
# 23                             General Catalyst Partners   3266.554158
# 24                                          DAG Ventures   3262.943187
# 25                                        Menlo Ventures   3235.161342
# 26                         VantagePoint Capital Partners   3113.076568
# 27                                       Canaan Partners   2990.851510
# 28                              Digital Sky Technologies   2921.807000
# 29                        Institutional Venture Partners   2906.762000
# ...                                                  ...           ...
# 10436                                      Virgo Capital           NaN
# 10437                                      Vishal Gondal           NaN
# 10438                               Vision Ridge Capital           NaN
# 10439                                              Visma           NaN
# 10440                              Vista Equity Partners           NaN
# 10441                              Vistage International           NaN
# 10442                                          Waynn Lue           NaN
# 10443                                         Weld North           NaN
# 10444                                  Wenceslao Casares           NaN
# 10445                                   WestMill Capital           NaN
# 10446  William C. Norris Institute at the University ...           NaN
# 10447                                    William Stefani           NaN
# 10448                                 Wynnchurch Capital           NaN
# 10449                               XMI High Growth Fund           NaN
# 10450                        Xanthas Creative Industries           NaN
# 10451                                          YellowBot           NaN
# 10452                        Yellowstone Energy Ventures           NaN
# 10453                                         Yoni Saban           NaN
# 10454                                         Young Sohn           NaN
# 10455                        Ziegler HealthVest Partners           NaN
# 10456                                Zinah Ventures, LLC           NaN
# 10457                                         Ziver Birg           NaN
# 10458                                           ZoomInfo           NaN
# 10459                                 b-to-v Partners AG           NaN
# 10460                                       for; to (do)           NaN
# 10461                                glendonTodd Capital           NaN
# 10462                                              iCamp           NaN
# 10463                                            iTACTIC           NaN
# 10464                                        mike schell           NaN
# 10465                                  venturecapital.de           NaN
#
# [10466 rows x 2 columns]

# %%
query = """
SELECT *
        
        FROM investments
        
        ORDER BY raised_amount_usd DESC
        LIMIT 1;
"""

top_round = pd.read_sql(query,conn)

# %%
top_round
# Out:
#   company_name company_category_code company_country_code company_state_code  \
# 0    Clearwire                mobile                  USA                 WA
#
#   company_region company_city investor_name investor_country_code  \
# 0        Seattle     Kirkland   BrightHouse                   USA
#
#   investor_state_code investor_region investor_city funding_round_type  \
# 0                  CA     Los Angeles  Santa Monica           post-ipo
#
#     funded_at funded_month funded_quarter funded_year  raised_amount_usd
# 0  2008-05-06      2008-05        2008-Q2        2008       3.200000e+09

# %%
query = """
SELECT *
        
        FROM investments
        WHERE raised_amount_usd IS NOT NULL
        ORDER BY raised_amount_usd ASC
        LIMIT 1;
"""

worst_round = pd.read_sql(query,conn)

# %%
worst_round
# Out:
#          company_name company_category_code company_country_code  \
# 0  PictureMe Universe           photo_video                  USA
#
#   company_state_code company_region company_city  \
# 0                 WI     Eau Claire   Eau Claire
#
#                                        investor_name investor_country_code  \
# 0  UW-Eau Claire Office of Research and Sponsored...                   USA
#
#   investor_state_code investor_region investor_city funding_round_type  \
# 0                  WI      Eau Claire    Eau Claire              other
#
#     funded_at funded_month funded_quarter funded_year  raised_amount_usd
# 0  2011-04-12      2011-04        2011-Q2        2011             1000.0
