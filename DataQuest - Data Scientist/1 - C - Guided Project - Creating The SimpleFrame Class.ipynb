# %% [markdown]
# # Guided Project: Creating The SimpleFrame Class

# %%
import pandas as pd
import numpy as np

import statistics as stats
import csv

# %%
data = pd.read_csv('music_data.csv')

# %%
data.head(3)
# Out:
#    Unnamed: 0                  Track Name         Artist  Streams        Date  \
# 0           0  Reggaetón Lento (Bailemos)           CNCO    19272  2017-01-01
# 1           1                    Chantaje        Shakira    19270  2017-01-01
# 2           2   Otra Vez (feat. J Balvin)  Zion & Lennox    15761  2017-01-01
#
#   Region
# 0     ec
# 1     ec
# 2     ec

# %%
class SimpleFrame():
    
    def __init__(self,filename):        
        self.name = filename
        self.data = list()
        self.columns = list()
        self.index = list()
        
        self.load()
        
    def load(self):        
        with open(self.name,'r') as f:
            raw = list(csv.reader(f))
            
        self.columns = raw[0]
        
        for row in raw[1:]:
            dict_row = dict()
            for index,col in enumerate(self.columns):
                dict_row[col]= row[index]
            self.data.append(dict_row)
            
        #self.data = raw[1:]
        
        for row in raw[1:]:
            self.index.append(row[1])
            
    def head(self,number):
        row_col = ' || '
        for col in self.columns:
            row_col+= col
            row_col+= ' || '
        print(row_col)   
        
        for row in self.data[:number]:
            row_str = ' || '
            for col in self.columns:
                row_str+=str(row[col])
                row_str+=' || '
            print(row_str)

    def shape(self):        
        self.length = len(self.columns)
        self.width = len(self.index)
        
        return [self.length,self.width]
   
    def add_new_column(self,name_col):
        self.columns.append(name_col)
        
        for row in self.data:
            row[name_col] = np.nan
            
    def apply(self,col,new_col,func,):
        self.add_new_column(new_col)
        for row in self.data:
            #row[new_col]=round(int(row[col])/1000,0)*1000
            row[new_col]=func(int(row[col]))
    
    def apply_col(self,col,func):
        values=list()
        for row in self.data:
            try:
                values.append(int(row[col]))
            except:
                pass
            
        return func(values)
    
    def subset(self,column,row):
        indice = self.index.index(row)
        ligne = self.data[indice]
        return ligne[column]
    
    def libelle(self,operation,value):
        message = 'The {} is about {}'.format(operation,value)
        print(message)
    
    def summary_stats(self):
        self.libelle('mean',self.apply_col('Streams',stats.mean))
        self.libelle('median',self.apply_col('Streams',stats.median))
        self.libelle('mode',self.apply_col('Streams',stats.mode))
        self.libelle('stdev',self.apply_col('Streams',stats.stdev))
        
        self.libelle('maximum',self.maximum('Streams'))
        self.libelle('minimum',self.minimum('Streams'))
        
    def maximum(self,col):
        maxi=0
        for row in self.data:
            if maxi < int(row[col]) :
                maxi=int(row[col])
        return maxi
        
    def minimum(self,col):
        mini=0
        for row in self.data:
            if mini > int(row[col]) :
                mini=int(row[col])
        return mini
    
    def top_song(self,year):
        maxi_song = 0
        for row in self.data:
            date_song = int(row['Date'][:4])        
            if date_song == year:
                if maxi_song < int(row['Streams']):
                    maxi_song = int(row['Streams'])
                    song = row['Track Name']
        return song
    
    def top_artist(self,year):
        maxi_song = 0
        for row in self.data:
            date_song = int(row['Date'][:4])        
            if date_song == year:
                if maxi_song < int(row['Streams']):
                    maxi_song = int(row['Streams'])
                    artist = row['Artist']
        return artist
        
    def top_artist_month(self,year,month):
        maxi_song = 0
        artist = ''
        for row in self.data:
            date_song = int(row['Date'][:4]) 
            position = row['Date'][5:].find('-')+5
            month_song = int(row['Date'][5:position])              
                
            if date_song == year and month_song==month:
                if maxi_song < int(row['Streams']):
                    maxi_song = int(row['Streams'])
                    artist = row['Artist']
        return artist
    
    def top_list(self,year):
        for month in range(1,13):
            top = self.top_artist_month(year,month)
            message = 'Mois n° {} - Top artist : {}'.format(month,top)
            print(message)
            
    def info(self):
        data_first = self.data[0]
        for col in self.columns:            
            type_data = type(data_first[col])
            print('Colonne {} - Type {}'.format(col,type_data))

# %%
spotify = SimpleFrame('music_data.csv')

# %%
spotify.info()
# Out:
# Colonne  - Type <class 'str'>
# Colonne Track Name - Type <class 'str'>
# Colonne Artist - Type <class 'str'>
# Colonne Streams - Type <class 'str'>
# Colonne Date - Type <class 'str'>
# Colonne Region - Type <class 'str'>

# %%
spotify.top_song(2017)
# Out:
# 'Despacito (Featuring Daddy Yankee)'

# %%
spotify.top_artist(2017)
# Out:
# 'Luis Fonsi'

# %%
spotify.top_list(2017)
# Out:
# Mois n° 1 - Top artist : Luis Fonsi
# Mois n° 2 - Top artist : Luis Fonsi
# Mois n° 3 - Top artist : Luis Fonsi
# Mois n° 4 - Top artist : Luis Fonsi
# Mois n° 5 - Top artist : Maluma
# Mois n° 6 - Top artist : Maluma
# Mois n° 7 - Top artist : J Balvin
# Mois n° 8 - Top artist : J Balvin
# Mois n° 9 - Top artist : Carlos Vives
# Mois n° 10 - Top artist : Carlos Vives
# Mois n° 11 - Top artist : Luis Fonsi
# Mois n° 12 - Top artist : Luis Fonsi

# %%
spotify.summary_stats()
# Out:
# The mean is about 6551.852857142857
# The median is about 4753.5
# The mode is about 3185
# The stdev is about 4835.224414499119
# The maximum is about 64238
# The minimum is about 0

# %%
def rounded(value):
    return round(int(value)/1000,0)*1000

spotify.apply('Streams','Streams_round',rounded)

# %%
spotify.head(3)
# Out:
#  ||  || Track Name || Artist || Streams || Date || Region || Streams_round ||
#  || 0 || Reggaetón Lento (Bailemos) || CNCO || 19272 || 2017-01-01 || ec || 19000.0 ||
#  || 1 || Chantaje || Shakira || 19270 || 2017-01-01 || ec || 19000.0 ||
#  || 2 || Otra Vez (feat. J Balvin) || Zion & Lennox || 15761 || 2017-01-01 || ec || 16000.0 ||

# %%
spotify.subset("Streams", "Thinking Out Loud")
# Out:
# '2430'

# %%
spotify.shape()
# Out:
# [6, 37100]

# %%
spotify.columns
# Out:
# ['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region']

# %%
spotify.index
# Out:
# ['Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  "Vente Pa' Ca",
#  'Safari',
#  'La Bicicleta',
#  'Ay Mi Dios',
#  'Andas En Mi Cabeza',
#  'Traicionera',
#  'Shaky Shaky',
#  'Vacaciones',
#  'Dile Que Tu Me Quieres',
#  'Let Me Love You',
#  'DUELE EL CORAZON',
#  'Chillax',
#  'Borro Cassette',
#  'One Dance',
#  'Closer',
#  'Starboy',
#  'Desde Esa Noche',
#  "Don't Wanna Know",
#  'La Gozadera',
#  '24K Magic',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Cuatro Babys',
#  'My Way',
#  'Gyal You A Party Animal',
#  'Baila Conmigo',
#  'Gyal You A Party Animal - Remix',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'Por Fin Te Encontré',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Bailame Despacio',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Hasta el Amanecer',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Bobo',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'In the Name of Love',
#  "Don't Let Me Down",
#  'Cheap Thrills',
#  'Fuego',
#  'Tan Fácil',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Treat You Better',
#  'Enamorándonos',
#  'Te Vas',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Te Quiero Pa´Mi',
#  'Heathens',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Deja Que Te Bese',
#  'Side To Side',
#  'Manicomio',
#  'Ruleta Rusa',
#  'I Feel It Coming',
#  'Ginza',
#  'Work',
#  'Cake By The Ocean',
#  'Picky',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'This Is What You Came For',
#  'Bailando - Spanish Version',
#  'Corazon De Seda (feat. Ozuna)',
#  'El Perdón',
#  'El Perdedor',
#  'Traicionera - Remix',
#  'Encantadora',
#  'Ride',
#  'Love Yourself',
#  'Encantadora - Remix',
#  'Materialista',
#  'Me Voy Enamorando - Remix',
#  'Vivir Mi Vida',
#  'Faded',
#  'Work from Home',
#  'El Perdedor - The Remix',
#  'Stressed Out',
#  'De Pies a Cabeza',
#  'Quisiera',
#  'Te Busco (feat. Nicky Jam)',
#  'Perfect Strangers',
#  'Hymn For The Weekend - Seeb Remix',
#  'El Chisme',
#  'Noche Loca',
#  'La Bicicleta - Remix',
#  'La Mordidita',
#  'La Ocasion (feat. Arcangel, Ozuna & Anuel Aa)',
#  'Sin Contrato',
#  'Locuras contigo',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Trumpets',
#  'Me Rehúso',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Nota de Amor',
#  'Me Ama Me Odia',
#  'Valió la Pena - Salsa Version',
#  'Me llamas',
#  'Time of Our Lives',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  'Safari',
#  "Vente Pa' Ca",
#  'Let Me Love You',
#  'Ay Mi Dios',
#  'Traicionera',
#  'La Bicicleta',
#  'Vacaciones',
#  'Closer',
#  'Dile Que Tu Me Quieres',
#  'Andas En Mi Cabeza',
#  'One Dance',
#  'Starboy',
#  'Shaky Shaky',
#  'Chillax',
#  "Don't Wanna Know",
#  'Cuatro Babys',
#  '24K Magic',
#  'DUELE EL CORAZON',
#  'My Way',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Borro Cassette',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'In the Name of Love',
#  'Desde Esa Noche',
#  'Gyal You A Party Animal - Remix',
#  'Baila Conmigo',
#  "Don't Let Me Down",
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Bailame Despacio',
#  'Cheap Thrills',
#  'Bobo',
#  'Treat You Better',
#  'Gyal You A Party Animal',
#  'La Gozadera',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Hasta el Amanecer',
#  'Fuego',
#  'Tan Fácil',
#  'Heathens',
#  'Te Vas',
#  'Por Fin Te Encontré',
#  'Te Quiero Pa´Mi',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'I Feel It Coming',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Side To Side',
#  'Enamorándonos',
#  'This Is What You Came For',
#  'Ride',
#  'Manicomio',
#  'Deja Que Te Bese',
#  'Faded',
#  'Ruleta Rusa',
#  'Work',
#  'Cake By The Ocean',
#  'Photograph',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Work from Home',
#  'Stressed Out',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Love Yourself',
#  'Corazon De Seda (feat. Ozuna)',
#  'Hymn For The Weekend - Seeb Remix',
#  'La Ocasion (feat. Arcangel, Ozuna & Anuel Aa)',
#  'Me Rehúso',
#  'Perfect Strangers',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Thinking Out Loud',
#  'Quisiera',
#  'Encantadora - Remix',
#  'Bajo el agua',
#  'El Chisme',
#  'Traicionera - Remix',
#  'Me Ama Me Odia',
#  'Just Hold On',
#  'Que Raro',
#  'Te Busco (feat. Nicky Jam)',
#  'Encantadora',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Ya Me Enteré',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Una y otra vez',
#  'Ginza',
#  'Black Beatles',
#  'Middle',
#  'The Greatest',
#  'El Perdedor - The Remix',
#  'De Pies a Cabeza',
#  'Me llamas',
#  "Say You Won't Let Go",
#  'All We Know',
#  'Mercy',
#  'El Perdedor',
#  'Starving',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  'Safari',
#  "Vente Pa' Ca",
#  'Let Me Love You',
#  'Ay Mi Dios',
#  'Closer',
#  'Vacaciones',
#  'Traicionera',
#  'Starboy',
#  'Dile Que Tu Me Quieres',
#  'One Dance',
#  "Don't Wanna Know",
#  'La Bicicleta',
#  'Andas En Mi Cabeza',
#  'Chillax',
#  '24K Magic',
#  'My Way',
#  'Cuatro Babys',
#  'Shaky Shaky',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Me Llamas (feat. Maluma) - Remix',
#  'DUELE EL CORAZON',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Borro Cassette',
#  'In the Name of Love',
#  "Don't Let Me Down",
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Treat You Better',
#  'Bailame Despacio',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Cheap Thrills',
#  'Gyal You A Party Animal - Remix',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Baila Conmigo',
#  'Desde Esa Noche',
#  'I Feel It Coming',
#  'Bobo',
#  'Heathens',
#  'Gyal You A Party Animal',
#  'Fuego',
#  'Te Quiero Pa´Mi',
#  'La Gozadera',
#  'Tan Fácil',
#  'Hasta el Amanecer',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Te Vas',
#  'Side To Side',
#  'Por Fin Te Encontré',
#  'Photograph',
#  'This Is What You Came For',
#  'Ride',
#  'Cake By The Ocean',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Enamorándonos',
#  'Work from Home',
#  'Deja Que Te Bese',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Ruleta Rusa',
#  'Faded',
#  'Manicomio',
#  'Work',
#  'Stressed Out',
#  'Thinking Out Loud',
#  'Una y otra vez',
#  'Me Rehúso',
#  'Love Yourself',
#  'Hymn For The Weekend - Seeb Remix',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Bajo el agua',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Perfect Strangers',
#  "Say You Won't Let Go",
#  'Quisiera',
#  'Just Hold On',
#  'Ya Me Enteré',
#  'Starving',
#  'La Ocasion (feat. Arcangel, Ozuna & Anuel Aa)',
#  'Corazon De Seda (feat. Ozuna)',
#  'Que Raro',
#  'El Chisme',
#  'All We Know',
#  'Black Beatles',
#  'Encantadora - Remix',
#  'Dueles',
#  'Encantadora',
#  'Mercy',
#  'The Greatest',
#  'Middle',
#  'Fake Love',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Traicionera - Remix',
#  'Me Ama Me Odia',
#  'Me llamas',
#  'Te Busco (feat. Nicky Jam)',
#  'El Perdedor - The Remix',
#  'The Scientist',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  "Vente Pa' Ca",
#  'Safari',
#  'Let Me Love You',
#  'Ay Mi Dios',
#  'Closer',
#  'Vacaciones',
#  'Traicionera',
#  'Starboy',
#  'Dile Que Tu Me Quieres',
#  "Don't Wanna Know",
#  '24K Magic',
#  'One Dance',
#  'La Bicicleta',
#  'Chillax',
#  'Andas En Mi Cabeza',
#  'My Way',
#  'Cuatro Babys',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Shaky Shaky',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'In the Name of Love',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'DUELE EL CORAZON',
#  'Bailame Despacio',
#  'I Feel It Coming',
#  'Borro Cassette',
#  "Don't Let Me Down",
#  'Treat You Better',
#  'Gyal You A Party Animal - Remix',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Cheap Thrills',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Side To Side',
#  'Te Quiero Pa´Mi',
#  'Desde Esa Noche',
#  'Heathens',
#  'Baila Conmigo',
#  'Bobo',
#  'Fuego',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Tan Fácil',
#  'This Is What You Came For',
#  'Gyal You A Party Animal',
#  'La Gozadera',
#  'Te Vas',
#  'Hasta el Amanecer',
#  'Photograph',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Just Hold On',
#  'Ride',
#  'Ruleta Rusa',
#  'Cake By The Ocean',
#  'Manicomio',
#  'Work from Home',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Deja Que Te Bese',
#  'Thinking Out Loud',
#  'Por Fin Te Encontré',
#  'Hymn For The Weekend - Seeb Remix',
#  'Work',
#  'Faded',
#  'Stressed Out',
#  'Enamorándonos',
#  'Una y otra vez',
#  'Me Rehúso',
#  'Bajo el agua',
#  "Say You Won't Let Go",
#  'Que Raro',
#  'Love Yourself',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'El Chisme',
#  'Ya Me Enteré',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Encantadora - Remix',
#  'All We Know',
#  'Mercy',
#  'Perfect Strangers',
#  'Quisiera',
#  'Traicionera - Remix',
#  'By Your Side',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Starving',
#  'Hear Me Now',
#  'Call On Me - Ryan Riback Extended Remix',
#  'La Ocasion (feat. Arcangel, Ozuna & Anuel Aa)',
#  'Black Beatles',
#  'Corazon De Seda (feat. Ozuna)',
#  'Fake Love',
#  'Quiero Que Vuelvas',
#  'The Greatest',
#  'Middle',
#  'Shed a Light',
#  'Para Enamorarte',
#  'Me Ama Me Odia',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  "Vente Pa' Ca",
#  'Safari',
#  'Let Me Love You',
#  'Ay Mi Dios',
#  'Vacaciones',
#  'Closer',
#  'Traicionera',
#  'Dile Que Tu Me Quieres',
#  'Starboy',
#  "Don't Wanna Know",
#  'Chillax',
#  'Cuatro Babys',
#  'La Bicicleta',
#  'My Way',
#  'One Dance',
#  'Andas En Mi Cabeza',
#  '24K Magic',
#  'Shaky Shaky',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'In the Name of Love',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Bailame Despacio',
#  'DUELE EL CORAZON',
#  'Borro Cassette',
#  'I Feel It Coming',
#  'Treat You Better',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Gyal You A Party Animal - Remix',
#  "Don't Let Me Down",
#  'Side To Side',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Cheap Thrills',
#  'Heathens',
#  'Desde Esa Noche',
#  'Bobo',
#  'This Is What You Came For',
#  'Te Quiero Pa´Mi',
#  'Baila Conmigo',
#  'Fuego',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Tan Fácil',
#  'Gyal You A Party Animal',
#  'La Gozadera',
#  'Just Hold On',
#  'Te Vas',
#  'Hasta el Amanecer',
#  'Photograph',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Cake By The Ocean',
#  'Ruleta Rusa',
#  'Manicomio',
#  'Deja Que Te Bese',
#  'Thinking Out Loud',
#  'Faded',
#  'Me Rehúso',
#  'Ride',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Stressed Out',
#  'Hymn For The Weekend - Seeb Remix',
#  'Ya Me Enteré',
#  'Una y otra vez',
#  'Por Fin Te Encontré',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Call On Me - Ryan Riback Extended Remix',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Work from Home',
#  'Enamorándonos',
#  'Love Yourself',
#  'Work',
#  'Bajo el agua',
#  'Encantadora - Remix',
#  'El Chisme',
#  'Quisiera',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  "Say You Won't Let Go",
#  'Hear Me Now',
#  'All We Know',
#  'La Ocasion (feat. Arcangel, Ozuna & Anuel Aa)',
#  'Que Raro',
#  'Corazon De Seda (feat. Ozuna)',
#  'Starving',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Shed a Light',
#  'Perfect Strangers',
#  'Quiero Que Vuelvas',
#  'By Your Side',
#  'Black Beatles',
#  'Mercy',
#  'Too Good',
#  'The Greatest',
#  'Traicionera - Remix',
#  'Fake Love',
#  'Me Ama Me Odia',
#  'El Perdedor - The Remix',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  "Vente Pa' Ca",
#  'Safari',
#  'Ay Mi Dios',
#  'Let Me Love You',
#  'Vacaciones',
#  'Traicionera',
#  'Closer',
#  'Dile Que Tu Me Quieres',
#  'Chillax',
#  'Starboy',
#  "Don't Wanna Know",
#  'La Bicicleta',
#  'Cuatro Babys',
#  'My Way',
#  'Andas En Mi Cabeza',
#  'One Dance',
#  '24K Magic',
#  'Shape of You',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Shaky Shaky',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'In the Name of Love',
#  'Bailame Despacio',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'DUELE EL CORAZON',
#  'Borro Cassette',
#  'Castle on the Hill',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Gyal You A Party Animal - Remix',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'I Feel It Coming',
#  'Treat You Better',
#  'Desde Esa Noche',
#  "Don't Let Me Down",
#  'Side To Side',
#  'Cheap Thrills',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Bobo',
#  'Te Quiero Pa´Mi',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Heathens',
#  'Baila Conmigo',
#  'Fuego',
#  'This Is What You Came For',
#  'Tan Fácil',
#  'Gyal You A Party Animal',
#  'La Gozadera',
#  'Te Vas',
#  'Photograph',
#  'Hasta el Amanecer',
#  'Just Hold On',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Manicomio',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Thinking Out Loud',
#  'Me Rehúso',
#  'Deja Que Te Bese',
#  'Ruleta Rusa',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Cake By The Ocean',
#  'Por Fin Te Encontré',
#  'Faded',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Enamorándonos',
#  'Ride',
#  'Stressed Out',
#  'El Chisme',
#  'Hymn For The Weekend - Seeb Remix',
#  'Corazon De Seda (feat. Ozuna)',
#  "Say You Won't Let Go",
#  'Ya Me Enteré',
#  'Encantadora - Remix',
#  'Bajo el agua',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Quisiera',
#  'Una y otra vez',
#  'Call On Me - Ryan Riback Extended Remix',
#  'Work',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Traicionera - Remix',
#  'La Ocasion (feat. Arcangel, Ozuna & Anuel Aa)',
#  'Love Yourself',
#  'Que Raro',
#  'Me Ama Me Odia',
#  'Work from Home',
#  'Hear Me Now',
#  'Perfect Strangers',
#  'El Perdedor - The Remix',
#  'Si Me Dices Que Si (feat. Nicky Jam)',
#  'All We Know',
#  'Black Beatles',
#  'By Your Side',
#  'Mercy',
#  'Shed a Light',
#  'Para Enamorarte',
#  'Encantadora',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  'Safari',
#  "Vente Pa' Ca",
#  'Ay Mi Dios',
#  'Vacaciones',
#  'Let Me Love You',
#  'Dile Que Tu Me Quieres',
#  'Traicionera',
#  'Shape of You',
#  'Closer',
#  'La Bicicleta',
#  'Chillax',
#  'Andas En Mi Cabeza',
#  'Shaky Shaky',
#  'Cuatro Babys',
#  "Don't Wanna Know",
#  'Starboy',
#  'Me Llamas (feat. Maluma) - Remix',
#  '24K Magic',
#  'One Dance',
#  'My Way',
#  'Borro Cassette',
#  'Bailame Despacio',
#  'DUELE EL CORAZON',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Gyal You A Party Animal - Remix',
#  'In the Name of Love',
#  'Castle on the Hill',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'I Feel It Coming',
#  'Desde Esa Noche',
#  'Te Quiero Pa´Mi',
#  'Bobo',
#  'Treat You Better',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Side To Side',
#  "Don't Let Me Down",
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Cheap Thrills',
#  'Tan Fácil',
#  'Baila Conmigo',
#  'Gyal You A Party Animal',
#  'Heathens',
#  'Fuego',
#  'La Gozadera',
#  'This Is What You Came For',
#  'Te Vas',
#  'Hasta el Amanecer',
#  'Manicomio',
#  'Photograph',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Ruleta Rusa',
#  'Just Hold On',
#  'Me Rehúso',
#  'Deja Que Te Bese',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Por Fin Te Encontré',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Enamorándonos',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Faded',
#  'Corazon De Seda (feat. Ozuna)',
#  'El Chisme',
#  'Cake By The Ocean',
#  'Traicionera - Remix',
#  'Ride',
#  'Si Me Dices Que Si (feat. Nicky Jam)',
#  'Thinking Out Loud',
#  'Stressed Out',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Encantadora - Remix',
#  'Quisiera',
#  'Que Raro',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Work',
#  'Me Ama Me Odia',
#  'Ya Me Enteré',
#  'El Perdedor - The Remix',
#  'Hymn For The Weekend - Seeb Remix',
#  'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)',
#  'Call On Me - Ryan Riback Extended Remix',
#  'Bajo el agua',
#  'Work from Home',
#  "Say You Won't Let Go",
#  'Ginza',
#  'Love Yourself',
#  'Hear Me Now',
#  'Perfect Strangers',
#  'Ando buscando',
#  'By Your Side',
#  'Alone',
#  'Shed a Light',
#  'De Pies a Cabeza',
#  'All We Know',
#  'Para Enamorarte',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  'Safari',
#  "Vente Pa' Ca",
#  'Ay Mi Dios',
#  'Vacaciones',
#  'Shape of You',
#  'Let Me Love You',
#  'Dile Que Tu Me Quieres',
#  'Traicionera',
#  'La Bicicleta',
#  'Chillax',
#  'Closer',
#  'Andas En Mi Cabeza',
#  'Shaky Shaky',
#  "Don't Wanna Know",
#  'Cuatro Babys',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Starboy',
#  '24K Magic',
#  'One Dance',
#  'My Way',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Borro Cassette',
#  'Bailame Despacio',
#  'In the Name of Love',
#  'Gyal You A Party Animal - Remix',
#  'DUELE EL CORAZON',
#  'Castle on the Hill',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'I Feel It Coming',
#  'Desde Esa Noche',
#  'Te Quiero Pa´Mi',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Side To Side',
#  'Bobo',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Cheap Thrills',
#  'Treat You Better',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Tan Fácil',
#  "Don't Let Me Down",
#  'Heathens',
#  'Gyal You A Party Animal',
#  'Fuego',
#  'La Gozadera',
#  'Baila Conmigo',
#  'Te Vas',
#  'Photograph',
#  'This Is What You Came For',
#  'Hasta el Amanecer',
#  'Ruleta Rusa',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Just Hold On',
#  'Manicomio',
#  'Por Fin Te Encontré',
#  'Me Rehúso',
#  'Si Me Dices Que Si (feat. Nicky Jam)',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Deja Que Te Bese',
#  'Enamorándonos',
#  'Traicionera - Remix',
#  'Thinking Out Loud',
#  'El Chisme',
#  'Faded',
#  'Stressed Out',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Corazon De Seda (feat. Ozuna)',
#  'Cake By The Ocean',
#  'Ride',
#  'Que Raro',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Quisiera',
#  'Encantadora - Remix',
#  'Work',
#  'Ya Me Enteré',
#  'Me Ama Me Odia',
#  'Hymn For The Weekend - Seeb Remix',
#  'Bajo el agua',
#  'Love Yourself',
#  'Call On Me - Ryan Riback Extended Remix',
#  'El Perdedor - The Remix',
#  'Shed a Light',
#  'Hear Me Now',
#  'Work from Home',
#  "Say You Won't Let Go",
#  'By Your Side',
#  'Ando buscando',
#  'El Perdedor',
#  'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)',
#  'Una y otra vez',
#  'Encantadora',
#  'Para Enamorarte',
#  'Perfect Strangers',
#  'Dueles',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  'Shape of You',
#  'Safari',
#  "Vente Pa' Ca",
#  'Let Me Love You',
#  'Vacaciones',
#  'Ay Mi Dios',
#  'Dile Que Tu Me Quieres',
#  'Traicionera',
#  'Closer',
#  'Chillax',
#  'Starboy',
#  "Don't Wanna Know",
#  'Andas En Mi Cabeza',
#  'La Bicicleta',
#  '24K Magic',
#  'One Dance',
#  'Cuatro Babys',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Shaky Shaky',
#  'My Way',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Castle on the Hill',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'I Feel It Coming',
#  'In the Name of Love',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'Borro Cassette',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Bailame Despacio',
#  'DUELE EL CORAZON',
#  'Gyal You A Party Animal - Remix',
#  'Side To Side',
#  'Te Quiero Pa´Mi',
#  'Treat You Better',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Photograph',
#  'Desde Esa Noche',
#  "Don't Let Me Down",
#  'Cheap Thrills',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Heathens',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Bobo',
#  'Fuego',
#  'Gyal You A Party Animal',
#  'Tan Fácil',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'Baila Conmigo',
#  'La Gozadera',
#  'Just Hold On',
#  'Te Vas',
#  'This Is What You Came For',
#  'Hasta el Amanecer',
#  'Deja Que Te Bese',
#  "Say You Won't Let Go",
#  'Manicomio',
#  'Ruleta Rusa',
#  'Me Rehúso',
#  'Thinking Out Loud',
#  'Si Me Dices Que Si (feat. Nicky Jam)',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Por Fin Te Encontré',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Faded',
#  'Bajo el agua',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Ride',
#  'Cake By The Ocean',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Ya Me Enteré',
#  'Mercy',
#  'Una y otra vez',
#  'El Chisme',
#  'Stressed Out',
#  'Enamorándonos',
#  'Call On Me - Ryan Riback Extended Remix',
#  'Dueles',
#  'Hymn For The Weekend - Seeb Remix',
#  'Work',
#  'Hear Me Now',
#  'By Your Side',
#  'Quisiera',
#  'All We Know',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Traicionera - Remix',
#  'Que Raro',
#  'Love Yourself',
#  'Encantadora - Remix',
#  'Shed a Light',
#  'The Scientist',
#  'Me Ama Me Odia',
#  'Alone',
#  'Fake Love',
#  'Soy Peor',
#  'Work from Home',
#  'Quiero Que Vuelvas',
#  'Corazon De Seda (feat. Ozuna)',
#  'Reggaetón Lento (Bailemos)',
#  'Chantaje',
#  'Otra Vez (feat. J Balvin)',
#  'Shape of You',
#  'Safari',
#  "Vente Pa' Ca",
#  'Let Me Love You',
#  'Ay Mi Dios',
#  'Vacaciones',
#  'Traicionera',
#  'Closer',
#  'Dile Que Tu Me Quieres',
#  'Starboy',
#  "Don't Wanna Know",
#  'Chillax',
#  '24K Magic',
#  'La Bicicleta',
#  'My Way',
#  'Andas En Mi Cabeza',
#  'One Dance',
#  'Cuatro Babys',
#  'Me Llamas (feat. Maluma) - Remix',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  'Castle on the Hill',
#  'Shaky Shaky',
#  'I Feel It Coming',
#  "We Don't Talk Anymore (feat. Selena Gomez)",
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'In the Name of Love',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'Side To Side',
#  'Bailame Despacio',
#  'Treat You Better',
#  'Borro Cassette',
#  'Photograph',
#  'DUELE EL CORAZON',
#  'Gyal You A Party Animal - Remix',
#  'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#  'Cheap Thrills',
#  "Don't Let Me Down",
#  'Te Quiero Pa´Mi',
#  'Heathens',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'Desde Esa Noche',
#  'Bobo',
#  'Tan Fácil',
#  'Fuego',
#  'Gyal You A Party Animal',
#  'This Is What You Came For',
#  'Just Hold On',
#  'Thinking Out Loud',
#  'La Gozadera',
#  'Baila Conmigo',
#  'Me Rehúso',
#  'Te Vas',
#  "Say You Won't Let Go",
#  'Manicomio',
#  'Faded',
#  'Cake By The Ocean',
#  'Stressed Out',
#  'Deja Que Te Bese',
#  'Hasta el Amanecer',
#  'Si Me Dices Que Si (feat. Nicky Jam)',
#  'Una y otra vez',
#  'Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#  'Bajo el agua',
#  'Ruleta Rusa',
#  'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#  'Call On Me - Ryan Riback Extended Remix',
#  'Ride',
#  'Por Fin Te Encontré',
#  'Enamorándonos',
#  'Ya Me Enteré',
#  'By Your Side',
#  'Hymn For The Weekend - Seeb Remix',
#  'Mercy',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#  'Quisiera',
#  'El Chisme',
#  'Hasta Que Se Seque el Malecón - Remix',
#  'Hear Me Now',
#  'Love Yourself',
#  'Shed a Light',
#  'Dueles',
#  'Work',
#  'Starving',
#  'Fake Love',
#  'All We Know',
#  'Soy Peor',
#  'Black Beatles',
#  'Traicionera - Remix',
#  'Que Raro',
#  'Work from Home',
#  'Encantadora - Remix',
#  'Mi Tesoro (feat. Nicky Jam)',
#  'Alone',
#  'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)',
#  'Me Ama Me Odia',
#  ...]

# %%
mot='2017-01-01'
mot[5:].find('-')
# Out:
# 2

# %%
row=dict()
row['Date']='2017-01-01'
position = row['Date'][5:].find('-')
#month_song = int(row['Date'][5:position])
print(position)
# Out:
# 2
